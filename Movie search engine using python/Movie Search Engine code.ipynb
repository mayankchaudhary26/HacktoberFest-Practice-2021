# %%
import sys
import time
import os
import pandas as pd
import csv
import random
from random import randrange
from pyfiglet import figlet_format
from termcolor import colored

# %%
# original_language 	original_title	overview	runtime	tagline	vote_average
original_language = []
original_title = []
overview = []
runtime = []
tagline = []
vote_average = []
v = 0
with open('data1.csv',encoding = "UTF-8") as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    for row in readCSV:
        original_language.append(row[0].upper())
        original_title.append(row[1].upper())
        overview.append(row[2].upper())
        runtime.append(row[3].upper())  
        tagline.append(row[4].upper())
        vote_average.append((row[5]).upper())
    #print(original_language,original_title,overview,runtime,tagline,vote_average)

# %%
def show(File = "user_details.txt"):
    file = open(File,"r")
    read = file.readline().split()
    file.close()
    print("Username :",read[0])
    print("Pin no :",read[1])
    print("---------------------")
    a = input("Press enter to countinue")
    print()
    menu()

# %%
def changePINFun(File = "user_details.txt"):
    file = open(File,"r")
    read = file.readline().split()
    file.close()
    new_pin = changepin1()     
    read[1]  =  new_pin 
    file = open(File,"w")
    read = file.write(read[0]+" "+read[1])
    file.close()
    menu()

# %%
def check(Password_Or_Pin):
    nums = [str(num) for num in range(10)]
    digitcount = []
    for var in Password_Or_Pin:
        if var not in nums:
            return True
        digitcount.append(Password_Or_Pin.count(var)) 
    check_count =  [VarInDigitcount for VarInDigitcount in digitcount if int(VarInDigitcount) != 1]  
    if len(check_count)>0:
        return True
    else:
        return False

# %%
def changepin1():
    new_pin = input("Enter new 4 Digit pin (should be unique 4-digits) : >")
    if len(new_pin)==4:
        while check(new_pin):
            return changepin1()
        else:
            return new_pin
    else:
        return changepin1()

# %%
def login():
    file = open("user_details.txt","a+")
    file.close()
    file = open("user_details.txt","r")
    data = file.readline().split()
    file.close()
    if len(data) == 0:
        print("You need to create an account first before login ")
        create()
    else:
        username, pin = data[0],data[1]
        asking_username = input("Please enter your username : \n > ")
        while asking_username != username:
            print("Invalid username \n try again")
            asking_username = input("Please enter your username : \n > ") 
        asking_pin = input("Please enter your PIN : \n > ")
        while asking_pin != pin:
            print("Invalid pin \n try again")
            asking_pin = input("Please enter your PIN : \n > ") 
        menu()

# %%
def create():
    file = open("user_details.txt","a+")
    file.close()
    file = open("user_details.txt","r")
    read = file.readline().split()
    file.close()
    if len(read)!=0:
        print("One account_already exist")
        login()
    else:
        file = open("user_details.txt","a+")
        username = input("Please enter your username : \n > ")     
        pin = input("Please enter  your PIN (should be unique 4-digits) : \n > ")
        while check(pin):
            print("Invalid card_pin \n try again")
            pin = input("Please enter your PIN (should be unique 4-digits) : \n > ")
        #print(username,pin)
        file.write(username + " " + pin)
        #print(file)
        file.close()
        print("You need to login again !")
        login()
    
#create()

# %%
def menu():
    print("="*51)
    print("~"*14,"  Movie search Engine  ","~"*14)
    print("="*51)
   
    print("1.     Show account information")
    print("2.     Change PIN number")
    print("3.     Movie search in the range of votes ")
    print("4.     Movie search in Maximum and minimum duration")
    print("5.     Search movie by their titles")
    print("6.     View the names of random movies")
    print("7.     Play Hangman ")
    print("8.     Terminate a program")
    print("="*50)
    print()
    print()
    Userchoice2 = input("Please enter the number of the servies that you want \n or press enter to quit : \n >")
    if Userchoice2 == "1":
        show()
    else:
        if Userchoice2 == "2":
            changePINFun()
        else:
            if Userchoice2 == "3":
                vote_average_basis()
            else:
                if Userchoice2 == "4":
                    runtime_basis()
                else:
                    if Userchoice2 == "5":
                        original_name()
                    else:
                        if Userchoice2 == "6":
                            random_names()
                        else:
                            if Userchoice2 == "7":
                                game()
                            else:
                                footer()

# %%
def vote_average_basis():
    print("Maximum vote == 10 and Minimum vote == 0")
    maxi = input("Maximum vote of movie : >> ").upper()
    mini = input("Minimum vote of movie : >> ").upper()
    count = []
    line = 0
    for c in range(len(vote_average)):
        if line == 0:
            line += 1
            continue
        else:
            if runtime[c] == "":
                pass
            elif float(maxi) >= float(vote_average[c]) and float(mini) <= float(vote_average[c]):
                count.append(c)
            else:
                pass
    MovieNo = 1
    for index in count: 
        print("\n\n---------------{} movie --------------".format(MovieNo))
        print("\nOriginal title of movie: >>",original_title[int(index)])
        print("\nPlot of the movie      : >>",overview[int(index)])
        print("\nRuntime of the movie   : >>",runtime[int(index)])
        print("\nTagline of the movie   : >>",tagline[int(index)])
        print("\nAverge vote            : >> ",vote_average[int(index)])
        print("="*69)
        MovieNo+=1
    print("Taking you back to menu")
    
    a = input("Press enter to countinue")
    menu()

# %%
def runtime_basis():
    maxi = input("Maximum runtime of movie : >> ").upper()
    mini = input("Minimum runtime of movie : >> ").upper()
    count = []
    line = 0
    for c in range(len(runtime)):
        if line == 0:
            line += 1
            continue
        else:
            if runtime[c] == "":
                pass
            elif float(maxi) >= float(runtime[c]) and float(mini) <= float(runtime[c]):
                count.append(c)
            else:
                pass
    MovieNo = 1
    for index in count: 
        print("\n\n---------------{} movie --------------".format(MovieNo))
        print("\nOriginal title of movie: >>",original_title[int(index)])
        print("\nPlot of the movie      : >>",overview[int(index)])
        print("\nRuntime of the movie   : >>",runtime[int(index)])
        print("\nTagline of the movie   : >>",tagline[int(index)])
        print("\nAverge vote            : >> ",vote_average[int(index)])
        print("="*69)
        MovieNo+=1
    
    a = input("Press enter to countinue")
    menu()

# %%
def original_name():
    title = input("Title of movie : >> ").upper() 
    count = []
    for c in range(len(original_title)):
        if title in str(original_title[c]):
            count.append(c)
        else:
            pass
    MovieNo = 1
    for index in count: 
        print("\n\n---------------{} movie --------------\n".format(MovieNo))
        print("\nOriginal title of movie: >>",original_title[int(index)])
        
        print("\nPlot of the movie      : >>",overview[int(index)])
        print("\nRuntime of the movie   : >>",runtime[int(index)])
        print("\nTagline of the movie   : >>",tagline[int(index)])
        print("\nAverge vote            : >> ",vote_average[int(index)])
        print("="*69)

        MovieNo+=1
    
    a = input("Press enter to countinue")
    menu()

# %%
def random_names():
    random_quantity = int(input("No. of movies You wants to see randomly !"))
    
    random_movies = []
    count = []

    for movies in range(random_quantity):
        random_index = randrange(len(original_title))
        count.append(random_index)
        
    MovieNo = 1
    for index in count: 
        print("\n\n---------------{} movie --------------".format(MovieNo))
        print("\nOriginal title of movie: >>",original_title[int(index)])
        print("\nPlot of the movie      : >>",overview[int(index)])
        print("\nRuntime of the movie   : >>",runtime[int(index)])
        print("\nTagline of the movie   : >>",tagline[int(index)])
        print("\nAverge vote            : >> ",vote_average[int(index)])
        print("="*69)
        MovieNo+=1
    a = input("Press enter to countinue")
    menu()

# %%
def game():
    
    print("H A N G M A N")
    print("             A game of words")
    print("-----------------------------------")
    words = ["python", "java", "kotlin", "javascript"]
    random.seed()
    while True:
        menu_selection = ""
        while menu_selection not in ["1", "2"]:
            menu_selection = input('Type "1" to play the game, "2" to go back to menu ')
        if menu_selection == "2":
            menu()
            break

        word = random.choice(words)
        word_length = len(word)
        hint = ["-"] * word_length
        lives = 8
        previous_guesses = []
        while lives > 0:
            print()
            print("".join(hint))
            guess = input("Input a letter: ")
            if len(guess) != 1:
                print("You should input a single letter")
                continue
            if not (guess.isascii() and guess.islower()):
                print("It is not an ASCII lowercase letter")
                continue
            if guess in previous_guesses:
                print("You already typed this letter")
                continue
            previous_guesses.append(guess)
            if guess in word:
                for i in range(word_length):
                    if word[i] == guess:
                        hint[i] = guess
                if "".join(hint) == word:
                    print("You guessed the word!")
                    print("You survived!")
                    break
            else:
                print("No such letter in the word")
                lives -= 1

        if lives == 0:
            print("You are hanged!")

        print()

# %%
def header():
    b=figlet_format("Movie Search",font='slant')
    c=colored(b,"red")
    print(c)
    d=figlet_format("Engine",font='slant')
    e=colored(d,"green")
    print(e)
    f=figlet_format("[With Hangman]",font='slant')
    g=colored(f,"blue")
    print(g)
    j=figlet_format("--------------",font='slant')
    i=colored(j,"yellow")
    print(i)

# %%
def footer():
    p=figlet_format("------+------",font='slant')
    q=colored(p)
    print(q)
    r=figlet_format("Made with love<3 -",font='slant')
    s=colored(r,"green")
    print(s)

    v=figlet_format("By Sudhanshu Tiwari",font='slant')
    w=colored(v,"red")
    print(w)
    
    z=figlet_format("          Waiting for you to browse movie again",font='digital')
    m=colored(z) 
    print(p,m,p)

# %%
if __name__=="__main__":
    header()
    userchoice = input("        Welcome to movie search and game engine \n\n> For creating an account enter (S)\n> for login enter (L)\n").upper()
    while userchoice != "L" and userchoice != "S":
        userchoice = input("For creating an account enter (S)\nfor login enter (L)\n").upper() 
    #print(userchoice)

    if userchoice == "L":
        login()
    else:
        create()
# Out:
#     __  ___           _         _____                      __
#    /  |/  /___ _   __(_)__     / ___/___  ____ ___________/ /_
#   / /|_/ / __ \ | / / / _ \    \__ \/ _ \/ __ `/ ___/ ___/ __ \
#  / /  / / /_/ / |/ / /  __/   ___/ /  __/ /_/ / /  / /__/ / / /
# /_/  /_/\____/|___/_/\___/   /____/\___/\__,_/_/   \___/_/ /_/
#
#
#     ______            _
#    / ____/___  ____ _(_)___  ___
#   / __/ / __ \/ __ `/ / __ \/ _ \
#  / /___/ / / / /_/ / / / / /  __/
# /_____/_/ /_/\__, /_/_/ /_/\___/
#             /____/
#
#      ____       ___ __  __
#     / _/ |     / (_) /_/ /_
#    / / | | /| / / / __/ __ \
#   / /  | |/ |/ / / /_/ / / /
#  / /   |__/|__/_/\__/_/ /_/
# /__/
#     __  __                                        ___
#    / / / /___ _____  ____ _____ ___  ____ _____  /  /
#   / /_/ / __ `/ __ \/ __ `/ __ `__ \/ __ `/ __ \ / /
#  / __  / /_/ / / / / /_/ / / / / / / /_/ / / / // /
# /_/ /_/\__,_/_/ /_/\__, /_/ /_/ /_/\__,_/_/ /_// /
#                   /____/                     /__/
#
#
#
#  ______________________________________________________________________________
# /_____/_____/_____/_____/_____/_____/_____/_____/_____/_____/_____/_____/_____/
#
#
#
#
#  ______
# /_____/
#
#
#
#         Welcome to movie search and game engine
#
# > For creating an account enter (S)
# > for login enter (L)
# l
# Please enter your username :
#  > sudhanshu
# Please enter your PIN :
#  > 1256
# Invalid pin
#  try again
# Please enter your PIN :
#  > 1234
# ===================================================
# ~~~~~~~~~~~~~~   Movie search Engine   ~~~~~~~~~~~~~~
# ===================================================
# 1.     Show account information
# 2.     Change PIN number
# 3.     Movie search in the range of votes
# 4.     Movie search in Maximum and minimum duration
# 5.     Search movie by their titles
# 6.     View the names of random movies
# 7.     Play Hangman
# 8.     Terminate a program
# ==================================================
#
#
# Please enter the number of the servies that you want
#  or press enter to quit :
#  >1
# Username : sudhanshu
# Pin no : 1234
# ---------------------
# Press enter to countinue
#
# ===================================================
# ~~~~~~~~~~~~~~   Movie search Engine   ~~~~~~~~~~~~~~
# ===================================================
# 1.     Show account information
# 2.     Change PIN number
# 3.     Movie search in the range of votes
# 4.     Movie search in Maximum and minimum duration
# 5.     Search movie by their titles
# 6.     View the names of random movies
# 7.     Play Hangman
# 8.     Terminate a program
# ==================================================
#
#
# Please enter the number of the servies that you want
#  or press enter to quit :
#  >2
# Enter new 4 Digit pin (should be unique 4-digits) : >1256
# ===================================================
# ~~~~~~~~~~~~~~   Movie search Engine   ~~~~~~~~~~~~~~
# ===================================================
# 1.     Show account information
# 2.     Change PIN number
# 3.     Movie search in the range of votes
# 4.     Movie search in Maximum and minimum duration
# 5.     Search movie by their titles
# 6.     View the names of random movies
# 7.     Play Hangman
# 8.     Terminate a program
# ==================================================
#
#
# Please enter the number of the servies that you want
#  or press enter to quit :
#  >1
# Username : sudhanshu
# Pin no : 1256
# ---------------------
# Press enter to countinue
#
# ===================================================
# ~~~~~~~~~~~~~~   Movie search Engine   ~~~~~~~~~~~~~~
# ===================================================
# 1.     Show account information
# 2.     Change PIN number
# 3.     Movie search in the range of votes
# 4.     Movie search in Maximum and minimum duration
# 5.     Search movie by their titles
# 6.     View the names of random movies
# 7.     Play Hangman
# 8.     Terminate a program
# ==================================================
#
#
# Please enter the number of the servies that you want
#  or press enter to quit :
#  >3
# Maximum vote == 10 and Minimum vote == 0
# Maximum vote of movie : >> 10
# Minimum vote of movie : >> 10
#
#
# ---------------1 movie --------------
#
# Original title of movie: >> STIFF UPPER LIPS
#
# Plot of the movie      : >> STIFF UPPER LIPS IS A BROAD PARODY OF BRITISH PERIOD FILMS, ESPECIALLY THE LAVISH MERCHANT-IVORY PRODUCTIONS OF THE 'EIGHTIES AND EARLY 'NINETIES. ALTHOUGH IT SPECIFICALLY TARGETS A ROOM WITH A VIEW, CHARIOTS OF FIRE, MAURICE, A PASSAGE TO INDIA, AND MANY OTHER FILMS, IN A MORE GENERAL WAY STIFF UPPER LIPS SATIRISES POPULAR PERCEPTIONS OF CERTAIN EDWARDIAN TRAITS: PROPRIETY, SEXUAL REPRESSION, XENOPHOBIA, AND CLASS SNOBBERY.
#
# Runtime of the movie   : >> 99
#
# Tagline of the movie   : >>
#
# Averge vote            : >>  10
# =====================================================================
#
#
# ---------------2 movie --------------
#
# Original title of movie: >> DANCER, TEXAS POP. 81
#
# Plot of the movie      : >> FOUR GUYS, BEST FRIENDS, HAVE GROWN UP TOGETHER IN DANCER, TEXAS POP. 81, A TINY TOWN IN WEST TEXAS. YEARS AGO, THEY MADE A SOLEMN VOW TO LEAVE TOWN TOGETHER AS SOON AS THEY GRADUATE. NOW, IT'S THAT WEEKEND AND THE TIME HAS COME TO "PUT UP OR SHUT UP." THE CLOCK IS TICKING AND AS ALL 81 PEOPLE IN THE TOWN WATCH, COMMENT, OFFER ADVICE AND PLACE BETS, THESE FOUR VERY DIFFERENT BOYS WITH UNIQUE BACKGROUNDS STRUGGLE WITH THE BIGGEST DECISION OF THEIR LIVES... WHETHER TO STAY OR LEAVE HOME.
#
# Runtime of the movie   : >> 97
#
# Tagline of the movie   : >> IN THE MIDDLE OF NOWHERE THEY HAD EVERYTHING
#
# Averge vote            : >>  10
# =====================================================================
#
#
# ---------------3 movie --------------
#
# Original title of movie: >> ME YOU AND FIVE BUCKS
#
# Plot of the movie      : >> A WOMANIZING YET LOVABLE LOSER, CHARLIE, A WAITER IN HIS EARLY 30'S WHO DREAMS OF SELLING HIS BOOK ENTITLED "7 STEPS OF HEALING THE MALE BROKEN HEART" FINDS HIMSELF STILL WORKING IN RESTAURANTS TO SURVIVE IN THE BIG APPLE. LOW ON CASH, HE'S LEFT WITH NO OTHER CHOICE BUT TO LOOK FOR A ROOMMATE TO SHARE HIS TINY STUDIO. SURPRISINGLY, THE FIRST PERSON TO ANSWER THE AD IS HIS EX AND ONLY LOVE OF HIS LIFE PAM, WHO BROKE HIS HEART AND DISAPPEARED WITHOUT REASON AND THE INSPIRATION BEHIND HIS BOOK. THE PAM HE REMEMBERED WAS A YOUTHFUL SPIRIT WITH LOTS OF MONEY WHO IS NOW BROKE AND DISHEVELED. A NEW STORY BEGINS AND IT IS UP TO CHARLIE TO FIND OUT WHY SHE RAN OUT ON HIM AND WHAT'S HAPPENED TO HER OVER THE PAST THREE YEARS. WITH A POTENTIAL NEW LOVE IN HIS LIFE, HE MUST GATHER THE STRENGTH TO HELP PAM GET BACK ON HER FEET WITHOUT REKINDLING OLD FEELINGS.
#
# Runtime of the movie   : >> 90
#
# Tagline of the movie   : >> A STORY ABOUT SECOND, SECOND CHANCES
#
# Averge vote            : >>  10
# =====================================================================
#
#
# ---------------4 movie --------------
#
# Original title of movie: >> LITTLE BIG TOP
#
# Plot of the movie      : >> AN AGING OUT OF WORK CLOWN RETURNS TO HIS SMALL HOMETOWN, RESIGNED TO SPEND THE REST OF HIS DAYS IN A DRUNKEN STUPOR. BUT WHEN HIS PASSION FOR CLOWNING IS REAWAKENED BY THE LOCAL AMATEUR CIRCUS HE FINDS HIS SMILE.
#
# Runtime of the movie   : >> 0
#
# Tagline of the movie   : >>
#
# Averge vote            : >>  10
# =====================================================================
# Taking you back to menu
# Press enter to countinue
# ===================================================
# ~~~~~~~~~~~~~~   Movie search Engine   ~~~~~~~~~~~~~~
# ===================================================
# 1.     Show account information
# 2.     Change PIN number
# 3.     Movie search in the range of votes
# 4.     Movie search in Maximum and minimum duration
# 5.     Search movie by their titles
# 6.     View the names of random movies
# 7.     Play Hangman
# 8.     Terminate a program
# ==================================================
# Please enter the number of the servies that you want
#  or press enter to quit :
#  >5
# Title of movie : >> avenger
#
#
# ---------------1 movie --------------
#
#
# Original title of movie: >> AVENGERS: AGE OF ULTRON
#
# Plot of the movie      : >> WHEN TONY STARK TRIES TO JUMPSTART A DORMANT PEACEKEEPING PROGRAM, THINGS GO AWRY AND EARTH’S MIGHTIEST HEROES ARE PUT TO THE ULTIMATE TEST AS THE FATE OF THE PLANET HANGS IN THE BALANCE. AS THE VILLAINOUS ULTRON EMERGES, IT IS UP TO THE AVENGERS TO STOP HIM FROM ENACTING HIS TERRIBLE PLANS, AND SOON UNEASY ALLIANCES AND UNEXPECTED ACTION PAVE THE WAY FOR AN EPIC AND UNIQUE GLOBAL ADVENTURE.
#
# Runtime of the movie   : >> 141
#
# Tagline of the movie   : >> A NEW AGE HAS COME.
#
# Averge vote            : >>  7.3
# =====================================================================
#
#
# ---------------2 movie --------------
#
#
# Original title of movie: >> THE AVENGERS
#
# Plot of the movie      : >> WHEN AN UNEXPECTED ENEMY EMERGES AND THREATENS GLOBAL SAFETY AND SECURITY, NICK FURY, DIRECTOR OF THE INTERNATIONAL PEACEKEEPING AGENCY KNOWN AS S.H.I.E.L.D., FINDS HIMSELF IN NEED OF A TEAM TO PULL THE WORLD BACK FROM THE BRINK OF DISASTER. SPANNING THE GLOBE, A DARING RECRUITMENT EFFORT BEGINS!
#
# Runtime of the movie   : >> 143
#
# Tagline of the movie   : >> SOME ASSEMBLY REQUIRED.
#
# Averge vote            : >>  7.4
# =====================================================================
#
#
# ---------------3 movie --------------
#
#
# Original title of movie: >> CAPTAIN AMERICA: THE FIRST AVENGER
#
# Plot of the movie      : >> PREDOMINANTLY SET DURING WORLD WAR II, STEVE ROGERS IS A SICKLY MAN FROM BROOKLYN WHO'S TRANSFORMED INTO SUPER-SOLDIER CAPTAIN AMERICA TO AID IN THE WAR EFFORT. ROGERS MUST STOP THE RED SKULL – ADOLF HITLER'S RUTHLESS HEAD OF WEAPONRY, AND THE LEADER OF AN ORGANIZATION THAT INTENDS TO USE A MYSTERIOUS DEVICE OF UNTOLD POWERS FOR WORLD DOMINATION.
#
# Runtime of the movie   : >> 124
#
# Tagline of the movie   : >> WHEN PATRIOTS BECOME HEROES
#
# Averge vote            : >>  6.6
# =====================================================================
#
#
# ---------------4 movie --------------
#
#
# Original title of movie: >> THE TOXIC AVENGER PART II
#
# Plot of the movie      : >> THE TOXIC AVENGER IS LURED TO TOKYO, JAPAN BY THE EVIL CORPORATION APOCALYPSE INC. SO WHILE THE TOXIC AVENGER IS FIGHTING CRIME IN TOKYO, APOCALYPSE INC. SPREAD EVIL IN TROMAVILLE.
#
# Runtime of the movie   : >> 96
#
# Tagline of the movie   : >>
#
# Averge vote            : >>  5.3
# =====================================================================
#
#
# ---------------5 movie --------------
#
#
# Original title of movie: >> THE TOXIC AVENGER
#
# Plot of the movie      : >> TROMAVILLE HAS A MONSTROUS NEW HERO. THE TOXIC AVENGER IS BORN WHEN MOP BOY MELVIN JUNKO FALLS INTO A VAT OF TOXIC WASTE. NOW EVILDOERS WILL HAVE A LOT TO LOSE.
#
# Runtime of the movie   : >> 82
#
# Tagline of the movie   : >> HE WAS 98LBS. OF SOLID NERD UNTIL HE BECAME...
#
# Averge vote            : >>  6.3
# =====================================================================
# Press enter to countinue
# ===================================================
# ~~~~~~~~~~~~~~   Movie search Engine   ~~~~~~~~~~~~~~
# ===================================================
# 1.     Show account information
# 2.     Change PIN number
# 3.     Movie search in the range of votes
# 4.     Movie search in Maximum and minimum duration
# 5.     Search movie by their titles
# 6.     View the names of random movies
# 7.     Play Hangman
# 8.     Terminate a program
# ==================================================
#
#
# Please enter the number of the servies that you want
#  or press enter to quit :
#  >5
# Title of movie : >> Terminator
#
#
# ---------------1 movie --------------
#
#
# Original title of movie: >> TERMINATOR SALVATION
#
# Plot of the movie      : >> ALL GROWN UP IN POST-APOCALYPTIC 2018, JOHN CONNOR MUST LEAD THE RESISTANCE OF HUMANS AGAINST THE INCREASINGLY DOMINATING MILITARISTIC ROBOTS. BUT WHEN MARCUS WRIGHT APPEARS, HIS EXISTENCE CONFUSES THE MISSION AS CONNOR TRIES TO DETERMINE WHETHER WRIGHT HAS COME FROM THE FUTURE OR THE PAST -- AND WHETHER HE'S FRIEND OR FOE.
#
# Runtime of the movie   : >> 115
#
# Tagline of the movie   : >> THE END BEGINS.
#
# Averge vote            : >>  5.9
# =====================================================================
#
#
# ---------------2 movie --------------
#
#
# Original title of movie: >> TERMINATOR 3: RISE OF THE MACHINES
#
# Plot of the movie      : >> IT'S BEEN 10 YEARS SINCE JOHN CONNOR SAVED EARTH FROM JUDGMENT DAY, AND HE'S NOW LIVING UNDER THE RADAR, STEERING CLEAR OF USING ANYTHING SKYNET CAN TRACE. THAT IS, UNTIL HE ENCOUNTERS T-X, A ROBOTIC ASSASSIN ORDERED TO FINISH WHAT T-1000 STARTED. GOOD THING CONNOR'S FORMER NEMESIS, THE TERMINATOR, IS BACK TO AID THE NOW-ADULT CONNOR … JUST LIKE HE PROMISED.
#
# Runtime of the movie   : >> 109
#
# Tagline of the movie   : >> THE MACHINES WILL RISE.
#
# Averge vote            : >>  5.9
# =====================================================================
#
#
# ---------------3 movie --------------
#
#
# Original title of movie: >> TERMINATOR GENISYS
#
# Plot of the movie      : >> THE YEAR IS 2029. JOHN CONNOR, LEADER OF THE RESISTANCE CONTINUES THE WAR AGAINST THE MACHINES. AT THE LOS ANGELES OFFENSIVE, JOHN'S FEARS OF THE UNKNOWN FUTURE BEGIN TO EMERGE WHEN TECOM SPIES REVEAL A NEW PLOT BY SKYNET THAT WILL ATTACK HIM FROM BOTH FRONTS; PAST AND FUTURE, AND WILL ULTIMATELY CHANGE WARFARE FOREVER.
#
# Runtime of the movie   : >> 126
#
# Tagline of the movie   : >> RESET THE FUTURE
#
# Averge vote            : >>  5.8
# =====================================================================
#
#
# ---------------4 movie --------------
#
#
# Original title of movie: >> TERMINATOR 2: JUDGMENT DAY
#
# Plot of the movie      : >> NEARLY 10 YEARS HAVE PASSED SINCE SARAH CONNOR WAS TARGETED FOR TERMINATION BY A CYBORG FROM THE FUTURE. NOW HER SON, JOHN, THE FUTURE LEADER OF THE RESISTANCE, IS THE TARGET FOR A NEWER, MORE DEADLY TERMINATOR. ONCE AGAIN, THE RESISTANCE HAS MANAGED TO SEND A PROTECTOR BACK TO ATTEMPT TO SAVE JOHN AND HIS MOTHER SARAH.
#
# Runtime of the movie   : >> 137
#
# Tagline of the movie   : >> IT'S NOTHING PERSONAL.
#
# Averge vote            : >>  7.7
# =====================================================================
#
#
# ---------------5 movie --------------
#
#
# Original title of movie: >> THE TERMINATOR
#
# Plot of the movie      : >> IN THE POST-APOCALYPTIC FUTURE, REIGNING TYRANNICAL SUPERCOMPUTERS TELEPORT A CYBORG ASSASSIN KNOWN AS THE "TERMINATOR" BACK TO 1984 TO KILL SARAH CONNOR, WHOSE UNBORN SON IS DESTINED TO LEAD INSURGENTS AGAINST 21ST CENTURY MECHANICAL HEGEMONY. MEANWHILE, THE HUMAN-RESISTANCE MOVEMENT DISPATCHES A LONE WARRIOR TO SAFEGUARD SARAH. CAN HE STOP THE VIRTUALLY INDESTRUCTIBLE KILLING MACHINE?
#
# Runtime of the movie   : >> 108
#
# Tagline of the movie   : >> YOUR FUTURE IS IN HIS HANDS.
#
# Averge vote            : >>  7.3
# =====================================================================
# Press enter to countinue
# ===================================================
# ~~~~~~~~~~~~~~   Movie search Engine   ~~~~~~~~~~~~~~
# ===================================================
# 1.     Show account information
# 2.     Change PIN number
# 3.     Movie search in the range of votes
# 4.     Movie search in Maximum and minimum duration
# 5.     Search movie by their titles
# 6.     View the names of random movies
# 7.     Play Hangman
# 8.     Terminate a program
# ==================================================
#
#
# Please enter the number of the servies that you want
#  or press enter to quit :
#  >4
# Maximum runtime of movie : >> 120
# Minimum runtime of movie : >> 120
#
#
# ---------------1 movie --------------
#
# Original title of movie: >> INDEPENDENCE DAY: RESURGENCE
#
# Plot of the movie      : >> WE ALWAYS KNEW THEY WERE COMING BACK. USING RECOVERED ALIEN TECHNOLOGY, THE NATIONS OF EARTH HAVE COLLABORATED ON AN IMMENSE DEFENSE PROGRAM TO PROTECT THE PLANET. BUT NOTHING CAN PREPARE US FOR THE ALIENS’ ADVANCED AND UNPRECEDENTED FORCE. ONLY THE INGENUITY OF A FEW BRAVE MEN AND WOMEN CAN BRING OUR WORLD BACK FROM THE BRINK OF EXTINCTION.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> WE HAD TWENTY YEARS TO PREPARE. SO DID THEY.
#
# Averge vote            : >>  4.9
# =====================================================================
#
#
# ---------------2 movie --------------
#
# Original title of movie: >> シン・ゴジラ
#
# Plot of the movie      : >> FROM THE MIND BEHIND EVANGELION COMES A HIT LARGER THAN LIFE.  WHEN A MASSIVE, GILLED MONSTER EMERGES FROM THE DEEP AND TEARS THROUGH THE CITY, THE GOVERNMENT SCRAMBLES TO SAVE ITS CITIZENS.  A RAG-TAG TEAM OF VOLUNTEERS CUTS THROUGH A WEB OF RED TAPE TO UNCOVER THE MONSTER'S WEAKNESS AND ITS MYSTERIOUS TIES TO A FOREIGN SUPERPOWER.  BUT TIME IS NOT ON THEIR SIDE - THE GREATEST CATASTROPHE TO EVER BEFALL THE WORLD IS ABOUT TO EVOLVE RIGHT BEFORE THEIR VERY EYES.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> A GOD INCARNATE. A CITY DOOMED.
#
# Averge vote            : >>  6.5
# =====================================================================
#
#
# ---------------3 movie --------------
#
# Original title of movie: >> MAD MAX: FURY ROAD
#
# Plot of the movie      : >> AN APOCALYPTIC STORY SET IN THE FURTHEST REACHES OF OUR PLANET, IN A STARK DESERT LANDSCAPE WHERE HUMANITY IS BROKEN, AND MOST EVERYONE IS CRAZED FIGHTING FOR THE NECESSITIES OF LIFE. WITHIN THIS WORLD EXIST TWO REBELS ON THE RUN WHO JUST MIGHT BE ABLE TO RESTORE ORDER. THERE'S MAX, A MAN OF ACTION AND A MAN OF FEW WORDS, WHO SEEKS PEACE OF MIND FOLLOWING THE LOSS OF HIS WIFE AND CHILD IN THE AFTERMATH OF THE CHAOS. AND FURIOSA, A WOMAN OF ACTION AND A WOMAN WHO BELIEVES HER PATH TO SURVIVAL MAY BE ACHIEVED IF SHE CAN MAKE IT ACROSS THE DESERT BACK TO HER CHILDHOOD HOMELAND.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> WHAT A LOVELY DAY.
#
# Averge vote            : >>  7.2
# =====================================================================
#
#
# ---------------4 movie --------------
#
# Original title of movie: >> THE BFG
#
# Plot of the movie      : >> THE BFG IS NO ORDINARY BONE-CRUNCHING GIANT. HE IS FAR TOO NICE AND JUMBLY. IT'S LUCKY FOR SOPHIE THAT HE IS. HAD SHE BEEN CARRIED OFF IN THE MIDDLE OF THE NIGHT BY THE BLOODBOTTLER, OR ANY OF THE OTHER GIANTS—RATHER THAN THE BFG—SHE WOULD HAVE SOON BECOME BREAKFAST. WHEN SOPHIE HEARS THAT THE GIANTS ARE FLUSH-BUNKING OFF TO ENGLAND TO SWOLLOMP A FEW NICE LITTLE CHIDDLERS, SHE DECIDES SHE MUST STOP THEM ONCE AND FOR ALL. AND THE BFG IS GOING TO HELP HER!
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> THE WORLD IS MORE GIANT THAN YOU CAN IMAGINE.
#
# Averge vote            : >>  6
# =====================================================================
#
#
# ---------------5 movie --------------
#
# Original title of movie: >> THE BOURNE LEGACY
#
# Plot of the movie      : >> NEW CIA OPERATIVE, AARON CROSS EXPERIENCES LIFE-OR-DEATH STAKES THAT HAVE BEEN TRIGGERED BY THE PREVIOUS ACTIONS OF JASON BOURNE.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> THERE WAS NEVER JUST ONE
#
# Averge vote            : >>  6
# =====================================================================
#
#
# ---------------6 movie --------------
#
# Original title of movie: >> MR. & MRS. SMITH
#
# Plot of the movie      : >> AFTER FIVE (OR SIX) YEARS OF VANILLA-WEDDED BLISS, ORDINARY SUBURBANITES JOHN AND JANE SMITH ARE STUCK IN A HUGE RUT. UNBEKNOWNST TO EACH OTHER, THEY ARE BOTH COOLLY LETHAL, HIGHLY-PAID ASSASSINS WORKING FOR RIVAL ORGANISATIONS. WHEN THEY DISCOVER THEY'RE EACH OTHER'S NEXT TARGET, THEIR SECRET LIVES COLLIDE IN A SPICY, EXPLOSIVE MIX OF WICKED COMEDY, PENT-UP PASSION, NONSTOP ACTION AND HIGH-TECH WEAPONRY.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> SMART AND SEXY.
#
# Averge vote            : >>  6.5
# =====================================================================
#
#
# ---------------7 movie --------------
#
# Original title of movie: >> AROUND THE WORLD IN 80 DAYS
#
# Plot of the movie      : >> A BET PITS A BRITISH INVENTOR, A CHINESE THIEF AND A FRENCH ARTIST ON A WORLDWIDE ADVENTURE THAT THEY CAN CIRCLE THE GLOBE IN 80 DAYS.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> LET YOUR IMAGINATION SOAR.
#
# Averge vote            : >>  5.7
# =====================================================================
#
#
# ---------------8 movie --------------
#
# Original title of movie: >> CREEPSHOW
#
# Plot of the movie      : >> INSPIRED BY THE E.C. COMICS OF THE 1950S, GEORGE A.ROMERO AND STEPHEN KING BRING FIVE TALES OF TERROR TO THE SCREEN.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> THE MOST FUN YOU'LL EVER HAVE... BEING SCARED!
#
# Averge vote            : >>  6.7
# =====================================================================
#
#
# ---------------9 movie --------------
#
# Original title of movie: >> HELLBOY II: THE GOLDEN ARMY
#
# Plot of the movie      : >> IN THIS CONTINUATION TO THE ADVENTURE OF THE DEMON SUPERHERO, AN EVIL ELF BREAKS AN ANCIENT PACT BETWEEN HUMANS AND CREATURES, AS HE DECLARES WAR AGAINST HUMANITY. HE IS ON A MISSION TO RELEASE THE GOLDEN ARMY, A DEADLY GROUP OF FIGHTING MACHINES THAT CAN DESTROY THE HUMAN RACE. AS HELL ON EARTH IS READY TO ERUPT, HELLBOY AND HIS CREW SET OUT TO DEFEAT THE EVIL PRINCE.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> SAVING THE WORLD IS A HELL OF A JOB.
#
# Averge vote            : >>  6.5
# =====================================================================
#
#
# ---------------10 movie --------------
#
# Original title of movie: >> DEEP IMPACT
#
# Plot of the movie      : >> A SEVEN-MILE-WIDE SPACE ROCK IS HURTLING TOWARD EARTH, THREATENING TO OBLITERATE THE PLANET. NOW, IT'S UP TO THE PRESIDENT OF THE UNITED STATES TO SAVE THE WORLD. HE APPOINTS A TOUGH-AS-NAILS VETERAN ASTRONAUT TO LEAD A JOINT AMERICAN-RUSSIAN CREW INTO SPACE TO DESTROY THE COMET BEFORE IMPACT. MEANWHILE, AN ENTERPRISING REPORTER USES HER SMARTS TO UNCOVER THE SCOOP OF THE CENTURY.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> HEAVEN AND EARTH ARE ABOUT TO COLLIDE.
#
# Averge vote            : >>  5.9
# =====================================================================
#
#
# ---------------11 movie --------------
#
# Original title of movie: >> OLYMPUS HAS FALLEN
#
# Plot of the movie      : >> WHEN THE WHITE HOUSE (SECRET SERVICE CODE: "OLYMPUS") IS CAPTURED BY A TERRORIST MASTERMIND AND THE PRESIDENT IS KIDNAPPED, DISGRACED FORMER PRESIDENTIAL GUARD MIKE BANNING FINDS HIMSELF TRAPPED WITHIN THE BUILDING. AS THE NATIONAL SECURITY TEAM SCRAMBLES TO RESPOND, THEY ARE FORCED TO RELY ON BANNING'S INSIDE KNOWLEDGE TO HELP RETAKE THE WHITE HOUSE, SAVE THE PRESIDENT AND AVERT AN EVEN BIGGER DISASTER.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> WHEN OUR FLAG FALLS OUR NATION WILL RISE.
#
# Averge vote            : >>  6.2
# =====================================================================
#
#
# ---------------12 movie --------------
#
# Original title of movie: >> THE LONG KISS GOODNIGHT
#
# Plot of the movie      : >> SAMANTHA CAINE, SUBURBAN HOMEMAKER, IS THE IDEAL MOM TO HER 8 YEAR OLD DAUGHTER CAITLIN. SHE LIVES IN HONESDALE, PA, HAS A JOB TEACHING SCHOOL AND MAKES THE BEST RICE KRISPIE TREATS IN TOWN. BUT WHEN SHE RECEIVES A BUMP ON HER HEAD, SHE BEGINS TO REMEMBER SMALL PARTS OF HER PREVIOUS LIFE AS A LETHAL, TOP-SECRET AGENT
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> WHAT'S FORGOTTEN IS NOT ALWAYS GONE.
#
# Averge vote            : >>  6.5
# =====================================================================
#
#
# ---------------13 movie --------------
#
# Original title of movie: >> COLLATERAL
#
# Plot of the movie      : >> CAB DRIVER MAX PICKS UP A MAN WHO OFFERS HIM $600 TO DRIVE HIM AROUND. BUT THE PROMISE OF EASY MONEY SOURS WHEN MAX REALIZES HIS FARE IS AN ASSASSIN.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> IT STARTED LIKE ANY OTHER NIGHT.
#
# Averge vote            : >>  7
# =====================================================================
#
#
# ---------------14 movie --------------
#
# Original title of movie: >> 西游记之孙悟空三打白骨精
#
# Plot of the movie      : >> TAKING PLACE 500 YEARS AFTER THE HAVOC IN HEAVEN, THE TANG PRIEST IS APPOINTED BY BUDDHA TO GO TO THE WEST TO FETCH THE SACRED SCRIPTURES, ONLY TO ACCIDENTALLY FREE THE MONKEY KING. WITH LADY WHITE (GONG LI) AIMING TO BREAK UP THE TEAM ASSEMBLED TO DEFEAT HER, THE MONKEY KING MUST FIGHT IN ORDER TO SAVE HIS WORLD!
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >>
#
# Averge vote            : >>  6
# =====================================================================
#
#
# ---------------15 movie --------------
#
# Original title of movie: >> MURDER BY NUMBERS
#
# Plot of the movie      : >> TENACIOUS HOMICIDE DETECTIVE CASSIE MAYWEATHER AND HER STILL-GREEN PARTNER ARE WORKING A MURDER CASE, ATTEMPTING TO PROFILE TWO MALEVOLENTLY BRILLIANT YOUNG MEN: COLD, CALCULATING KILLERS WHOSE DARK SECRETS MIGHT EXPLAIN THEIR CRIMES.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> THE ONLY FLAW IN THEIR PLAN WAS HER.
#
# Averge vote            : >>  6
# =====================================================================
#
#
# ---------------16 movie --------------
#
# Original title of movie: >> CHAPPIE
#
# Plot of the movie      : >> EVERY CHILD COMES INTO THE WORLD FULL OF PROMISE, AND NONE MORE SO THAN CHAPPIE: HE IS GIFTED, SPECIAL, A PRODIGY. LIKE ANY CHILD, CHAPPIE WILL COME UNDER THE INFLUENCE OF HIS SURROUNDINGS—SOME GOOD, SOME BAD—AND HE WILL RELY ON HIS HEART AND SOUL TO FIND HIS WAY IN THE WORLD AND BECOME HIS OWN MAN. BUT THERE'S ONE THING THAT MAKES CHAPPIE DIFFERENT FROM ANY ONE ELSE: HE IS A ROBOT.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> I AM CONSCIOUSNESS. I AM ALIVE. I AM CHAPPIE.
#
# Averge vote            : >>  6.6
# =====================================================================
#
#
# ---------------17 movie --------------
#
# Original title of movie: >> K-PAX
#
# Plot of the movie      : >> PROT IS A PATIENT AT A MENTAL HOSPITAL WHO CLAIMS TO BE FROM A FAR AWAY PLANET. HIS PSYCHIATRIST TRIES TO HELP HIM, ONLY TO BEGIN TO DOUBT HIS OWN EXPLANATIONS.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> CHANGE THE WAY YOU LOOK AT THE WORLD.
#
# Averge vote            : >>  7.1
# =====================================================================
#
#
# ---------------18 movie --------------
#
# Original title of movie: >> BLADE
#
# Plot of the movie      : >> WHEN BLADE'S MOTHER WAS BITTEN BY A VAMPIRE DURING PREGNANCY, SHE DID NOT KNOW THAT SHE GAVE HER SON A SPECIAL GIFT WHILE DYING: ALL THE GOOD VAMPIRE ATTRIBUTES IN COMBINATION WITH THE BEST HUMAN SKILLS. BLADE AND HIS MENTOR WHISTLER BATTLE AN EVIL VAMPIRE REBEL (DEACON FROST) WHO PLANS TO TAKE OVER THE OUTDATED VAMPIRE COUNCIL, CAPTURE BLADE AND RESURRECT VORACIOUS BLOOD GOD LA MAGRA.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> PART MAN. PART VAMPIRE. ALL HERO.
#
# Averge vote            : >>  6.5
# =====================================================================
#
#
# ---------------19 movie --------------
#
# Original title of movie: >> ARGO
#
# Plot of the movie      : >> AS THE IRANIAN REVOLUTION REACHES A BOILING POINT, A CIA 'EXFILTRATION' SPECIALIST CONCOCTS A RISKY PLAN TO FREE SIX AMERICANS WHO HAVE FOUND SHELTER AT THE HOME OF THE CANADIAN AMBASSADOR.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> THE MOVIE WAS FAKE. THE MISSION WAS REAL.
#
# Averge vote            : >>  7.1
# =====================================================================
#
#
# ---------------20 movie --------------
#
# Original title of movie: >> 15 MINUTES
#
# Plot of the movie      : >> WHEN EASTERN EUROPEAN CRIMINALS OLEG AND EMIL COME TO NEW YORK CITY TO PICK UP THEIR SHARE OF A HEIST SCORE, OLEG STEALS A VIDEO CAMERA AND STARTS FILMING THEIR ACTIVITIES, BOTH LEGAL AND ILLEGAL. WHEN THEY LEARN HOW THE AMERICAN MEDIA CIRCUS CAN MAKE A REMORSELESS KILLER LOOK LIKE THE VICTIM AND MAKE THEM RICH, THEY TARGET MEDIA-SAVVY NYPD HOMICIDE DETECTIVE EDDIE FLEMMING AND MEDIA-NAIVE FDNY FIRE MARSHAL JORDY WARSAW, THE COPS INVESTIGATING THEIR MURDER AND TORCHING OF THEIR FORMER CRIMINAL PARTNER, FILMING EVERYTHING TO SELL TO THE LOCAL TABLOID TV SHOW "TOP STORY."
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> AMERICA LIKES TO WATCH
#
# Averge vote            : >>  5.7
# =====================================================================
#
#
# ---------------21 movie --------------
#
# Original title of movie: >> THE SOCIAL NETWORK
#
# Plot of the movie      : >> ON A FALL NIGHT IN 2003, HARVARD UNDERGRAD AND COMPUTER PROGRAMMING GENIUS MARK ZUCKERBERG SITS DOWN AT HIS COMPUTER AND HEATEDLY BEGINS WORKING ON A NEW IDEA. IN A FURY OF BLOGGING AND PROGRAMMING, WHAT BEGINS IN HIS DORM ROOM AS A SMALL SITE AMONG FRIENDS SOON BECOMES A GLOBAL SOCIAL NETWORK AND A REVOLUTION IN COMMUNICATION. A MERE SIX YEARS AND 500 MILLION FRIENDS LATER, MARK ZUCKERBERG IS THE YOUNGEST BILLIONAIRE IN HISTORY... BUT FOR THIS ENTREPRENEUR, SUCCESS LEADS TO BOTH PERSONAL AND LEGAL COMPLICATIONS.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> YOU DON'T GET TO 500 MILLION FRIENDS WITHOUT MAKING A FEW ENEMIES.
#
# Averge vote            : >>  7.1
# =====================================================================
#
#
# ---------------22 movie --------------
#
# Original title of movie: >> EIGHT BELOW
#
# Plot of the movie      : >> IN THE ANTARCTIC, AFTER AN EXPEDITION WITH DR. DAVIS MCCLAREN, THE SLED DOG TRAINER JERRY SHEPHERD HAS TO LEAVE THE POLAR BASE WITH HIS COLLEAGUES DUE TO THE PROXIMITY OF A HEAVY SNOW STORM. HE TIES HIS DOGS TO BE RESCUED AFTER, BUT THE MISSION IS CALLED-OFF AND THE DOGS ARE LEFT ALONE AT THEIR OWN FORTUNE. FOR SIX MONTHS, JERRY TRIES TO FIND A SPONSOR FOR A RESCUE MISSION.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> THE MOST AMAZING STORY OF SURVIVAL, FRIENDSHIP, AND ADVENTURE EVER TOLD.
#
# Averge vote            : >>  6.7
# =====================================================================
#
#
# ---------------23 movie --------------
#
# Original title of movie: >> WATER FOR ELEPHANTS
#
# Plot of the movie      : >> IN THIS CAPTIVATING DEPRESSION-ERA MELODRAMA, IMPETUOUS VETERINARY STUDENT JACOB JANKOWSKI JOINS A CELEBRATED CIRCUS AS AN ANIMAL CARETAKER BUT FACES A WRENCHING DILEMMA WHEN HE'S TRANSFIXED BY ANGELIC MARRIED PERFORMER MARLENA.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> LIFE IS THE MOST SPECTACULAR SHOW ON EARTH.
#
# Averge vote            : >>  6.7
# =====================================================================
#
#
# ---------------24 movie --------------
#
# Original title of movie: >> ALIVE
#
# Plot of the movie      : >> THE AMAZING, TRUE STORY OF A URUGUAYAN RUGBY TEAM'S PLANE THAT CRASHED IN THE MIDDLE OF THE ANDES MOUNTAINS, AND THEIR IMMENSE WILL TO SURVIVE AND PULL THROUGH ALIVE, FORCED TO DO ANYTHING AND EVERYTHING THEY COULD TO STAY ALIVE ON MEAGER RATIONS AND THROUGH THE FREEZING COLD.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> THEY SURVIVED THE IMPOSSIBLE...BY DOING THE UNTHINKABLE.
#
# Averge vote            : >>  6.7
# =====================================================================
#
#
# ---------------25 movie --------------
#
# Original title of movie: >> TAKING WOODSTOCK
#
# Plot of the movie      : >> THE STORY OF ELLIOT TIBER AND HIS FAMILY, WHO INADVERTENTLY PLAYED A PIVOTAL ROLE IN MAKING THE FAMED WOODSTOCK MUSIC AND ARTS FESTIVAL INTO THE HAPPENING THAT IT WAS. WHEN ELLIOT HEARS THAT A NEIGHBORING TOWN HAS PULLED THE PERMIT ON A HIPPIE MUSIC FESTIVAL, HE CALLS THE PRODUCERS THINKING HE COULD DRUM UP SOME MUCH-NEEDED BUSINESS FOR HIS PARENTS' RUN-DOWN MOTEL. THREE WEEKS LATER, HALF A MILLION PEOPLE ARE ON THEIR WAY TO HIS NEIGHBOR’S FARM IN WHITE LAKE, NEW YORK, AND ELLIOT FINDS HIMSELF SWEPT UP IN A GENERATION-DEFINING EXPERIENCE THAT WOULD CHANGE HIS LIFE–AND AMERICAN CULTURE–FOREVER.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> A GENERATION BEGAN IN HIS BACKYARD.
#
# Averge vote            : >>  6.2
# =====================================================================
#
#
# ---------------26 movie --------------
#
# Original title of movie: >> RENDITION
#
# Plot of the movie      : >> WHEN AN EGYPTIAN TERRORISM SUSPECT "DISAPPEARS" ON A FLIGHT FROM AFRICA TO WASHINGTON DC, HIS AMERICAN WIFE AND A CIA ANALYST FIND THEMSELVES CAUGHT UP IN A STRUGGLE TO SECURE HIS RELEASE FROM A SECRET DETENTION FACILITY SOMEWHERE OUTSIDE THE US.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> WHAT IF SOMEONE YOU LOVE...JUST DISAPPEARED?
#
# Averge vote            : >>  6.2
# =====================================================================
#
#
# ---------------27 movie --------------
#
# Original title of movie: >> THE STATEMENT
#
# Plot of the movie      : >> THE FILM IS SET IN FRANCE IN THE 1990S, THE FRENCH WERE DEFEATED BY THE GERMANS EARLY IN WORLD WAR II, AN ARMISTICE WAS SIGNED IN 1940 WHICH EFFECTIVELY SPLIT FRANCE INTO A GERMAN OCCUPIED PART IN THE NORTH AND A SEMI-INDEPENDENT PART IN THE SOUTH WHICH BECAME KNOWN AS VICHY FRANCE. IN REALITY THE VICHY GOVERNMENT WAS A PUPPET REGIME CONTROLLED BY THE GERMANS. PART OF THE AGREEMENT WAS THAT THE VICHY GOVERNMENT WOULD ASSIST WITH THE 'CLEANSING' OF JEWS FROM FRANCE. THE VICHY GOVERNMENT FORMED A POLICE FORCE CALLED THE MILICE, WHO WORKED WITH THE GERMANS...
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> AT THE END OF WORLD WAR II, MANY OF THOSE INVOLVED IN WAR CRIMES WERE PROSECUTED. SOME GOT AWAY. UNTIL NOW.
#
# Averge vote            : >>  5.9
# =====================================================================
#
#
# ---------------28 movie --------------
#
# Original title of movie: >> THE GREATEST GAME EVER PLAYED
#
# Plot of the movie      : >> A BIOPIC OF 20-YEAR-OLD FRANCIS OUIMET WHO DEFEATED HIS GOLFING IDOL AND 1900 US OPEN CHAMPION, HARRY VARDON.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> BASED ON A TRUE STORY
#
# Averge vote            : >>  6.9
# =====================================================================
#
#
# ---------------29 movie --------------
#
# Original title of movie: >> THE 33
#
# Plot of the movie      : >> BASED ON A TRUE STORY ABOUT THE COLLAPSE AT THE MINE IN SAN JOSE, CHILE THAT  LEFT 33 MINERS ISOLATED UNDERGROUND FOR 69 DAYS.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> HOPE RUNS DEEP
#
# Averge vote            : >>  6
# =====================================================================
#
#
# ---------------30 movie --------------
#
# Original title of movie: >> SCREAM 2
#
# Plot of the movie      : >> TWO YEARS AFTER THE TERRIFYING EVENTS THAT OCCURRED IN WOODSBORO, SIDNEY IS NOW ATTENDING WINDSOR COLLEGE IN CINCINNATI, AND GALE WEATHERS' BEST SELLING BOOK ON SIDNEY'S LIFE HAS NOW BEEN MADE INTO A MAJOR MOTION PICTURE. WHEN TWO COLLEGE STUDENTS ARE KILLED IN A THEATRE WHILE WATCHING THE NEW FILM 'STAB', SIDNEY KNOWS DEEP DOWN THAT HISTORY IS REPEATING ITSELF.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> SOMEONE HAS TAKEN THEIR LOVE OF SEQUELS ONE STEP TOO FAR.
#
# Averge vote            : >>  6.1
# =====================================================================
#
#
# ---------------31 movie --------------
#
# Original title of movie: >> THE BRIDGE OF SAN LUIS REY
#
# Plot of the movie      : >> THE BRIDGE OF SAN LUIS REY IS AMERICAN AUTHOR THORNTON WILDER'S SECOND NOVEL, FIRST PUBLISHED IN 1927 TO WORLDWIDE ACCLAIM. IT TELLS THE STORY OF SEVERAL INTERRELATED PEOPLE WHO DIE IN THE COLLAPSE OF AN INCA ROPE-FIBER SUSPENSION BRIDGE IN PERU, AND THE EVENTS THAT LEAD UP TO THEIR BEING ON THE BRIDGE.[ A FRIAR WHO HAS WITNESSED THE TRAGIC ACCIDENT THEN GOES ABOUT INQUIRING INTO THE LIVES OF THE VICTIMS, SEEKING SOME SORT OF COSMIC ANSWER TO THE QUESTION OF WHY EACH HAD TO DIE. THE NOVEL WON THE PULITZER PRIZE IN 1928.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >>
#
# Averge vote            : >>  5.4
# =====================================================================
#
#
# ---------------32 movie --------------
#
# Original title of movie: >> SWING VOTE
#
# Plot of the movie      : >> IN A REMARKABLE TURN OF EVENTS, THE RESULT OF THE PRESIDENTIAL ELECTION COMES DOWN TO ONE MAN'S VOTE.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> ONE ORDINARY GUY IS GIVING THE CANDIDATES A REASON TO RUN.
#
# Averge vote            : >>  5.8
# =====================================================================
#
#
# ---------------33 movie --------------
#
# Original title of movie: >> HOME ALONE 2: LOST IN NEW YORK
#
# Plot of the movie      : >> INSTEAD OF FLYING TO FLORIDA WITH HIS FOLKS, KEVIN ENDS UP ALONE IN NEW YORK, WHERE HE GETS A HOTEL ROOM WITH HIS DAD'S CREDIT CARD—DESPITE PROBLEMS FROM A CLERK AND MEDDLING BELLBOY. BUT WHEN KEVIN RUNS INTO HIS OLD NEMESES, THE WET BANDITS, HE'S DETERMINED TO FOIL THEIR PLANS TO ROB A TOY STORE ON CHRISTMAS EVE.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> HE'S UP PAST HIS BEDTIME IN THE CITY THAT NEVER SLEEPS.
#
# Averge vote            : >>  6.3
# =====================================================================
#
#
# ---------------34 movie --------------
#
# Original title of movie: >> CAPITALISM: A LOVE STORY
#
# Plot of the movie      : >> MICHAEL MOORE'S CAPITALISM: A LOVE STORY COMES HOME TO THE ISSUE HE'S BEEN EXAMINING THROUGHOUT HIS CAREER: THE DISASTROUS IMPACT OF CORPORATE DOMINANCE ON THE EVERYDAY LIVES OF AMERICANS (AND BY DEFAULT, THE REST OF THE WORLD).
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> ASK NOT WHAT YOUR C.E.O. CAN DO FOR YOU, BUT WHAT YOU CAN DO FOR YOUR C.E.O.
#
# Averge vote            : >>  7
# =====================================================================
#
#
# ---------------35 movie --------------
#
# Original title of movie: >> МОНГОЛ
#
# Plot of the movie      : >> THE STORY RECOUNTS THE EARLY LIFE OF GENGHIS KHAN, A SLAVE WHO WENT ON TO CONQUER HALF THE WORLD IN THE 11TH CENTURY.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> GREATNESS COMES TO THOSE WHO TAKE IT.
#
# Averge vote            : >>  6.5
# =====================================================================
#
#
# ---------------36 movie --------------
#
# Original title of movie: >> BOBBY JONES: STROKE OF GENIUS
#
# Plot of the movie      : >> THE STORY OF GOLF ICON AND LEGEND, BOBBY JONES, WHO RETIRED FROM COMPETITION AT THE TENDER AGE OF 28.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >>
#
# Averge vote            : >>  5.5
# =====================================================================
#
#
# ---------------37 movie --------------
#
# Original title of movie: >> ESCOBAR: PARADISE LOST
#
# Plot of the movie      : >> FOR PABLO ESCOBAR FAMILY IS EVERYTHING. WHEN YOUNG SURFER NICK FALLS FOR ESCOBAR'S NIECE, MARIA, HE FINDS HIS LIFE ON THE LINE WHEN HE'S PULLED INTO THE DANGEROUS WORLD OF THE FAMILY BUSINESS.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> WELCOME TO THE FAMILY
#
# Averge vote            : >>  6.1
# =====================================================================
#
#
# ---------------38 movie --------------
#
# Original title of movie: >> BECOMING JANE
#
# Plot of the movie      : >> A BIOGRAPHICAL PORTRAIT OF A PRE-FAME JANE AUSTEN AND HER ROMANCE WITH A YOUNG IRISHMAN.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> HER OWN LIFE IS HER GREATEST INSPIRATION.
#
# Averge vote            : >>  6.9
# =====================================================================
#
#
# ---------------39 movie --------------
#
# Original title of movie: >> THE YOUNG MESSIAH
#
# Plot of the movie      : >> TELLS THE STORY OF JESUS CHRIST AT AGE SEVEN AS HE AND HIS FAMILY DEPART EGYPT TO RETURN HOME TO NAZARETH. TOLD FROM HIS CHILDHOOD PERSPECTIVE, IT FOLLOWS YOUNG JESUS AS HE GROWS INTO HIS RELIGIOUS IDENTITY.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> BEFORE HE WAS THE SAVIOR, HE WAS A CHILD.
#
# Averge vote            : >>  6.4
# =====================================================================
#
#
# ---------------40 movie --------------
#
# Original title of movie: >> 卧虎藏龙
#
# Plot of the movie      : >> TWO WARRIORS IN PURSUIT OF A STOLEN SWORD AND A NOTORIOUS FUGITIVE ARE LED TO AN IMPETUOUS, PHYSICALLY-SKILLED, TEENAGE NOBLEMAN'S DAUGHTER, WHO IS AT A CROSSROADS IN HER LIFE.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> A TIMELESS STORY OF STRENGTH, SECRETS AND TWO WARRIORS WHO WOULD NEVER SURRENDER.
#
# Averge vote            : >>  7.2
# =====================================================================
#
#
# ---------------41 movie --------------
#
# Original title of movie: >> 해운대
#
# Plot of the movie      : >> MAN-SIK AND YEON-HEE, ARE UNSURE AS TO WHETHER THEY CAN OVERCOME PAST WOUNDS AND CONTINUE BEING A COUPLE. DR. KIM, WHO CAUTIONS AGAINST A POSSIBLE MEGA-TSUNAMI AT HAEUNDAE, COLLAPSES IN AGONY SPRINGING FROM AN UNEXPECTED TURN-UP OF HIS DAUGHTER AND DIVORCED WIFE. HYOUNG-SIK, AFTER RESCUING A WOMAN FROM SEOUL, RIDES OUT A FEROCIOUS STORM TO GLADDEN HER HEART. A TSUNAMI WHICH DESTROYS HAEUNDAE SYMBOLIZES THE ESTABLISHMENT OF A TYPICAL AXIS CALLED PROVOCATION OF CONFLICTS, AND LATER THE INNER SPACES OF THE COUPLES WITHOUT ANYTHING LEFT BEHIND AFTER ALL CONFLICTS HAVE ENDED
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >>
#
# Averge vote            : >>  6.5
# =====================================================================
#
#
# ---------------42 movie --------------
#
# Original title of movie: >> WHERE THE HEART IS
#
# Plot of the movie      : >> NOVALEE NATION IS A 17-YEAR-OLD TENNESSEE TRANSIENT WHO HAS TO GROW UP IN A HURRY WHEN SHE'S LEFT PREGNANT AND ABANDONED BY HER BOYFRIEND ON A ROADSIDE IN SEQUOYAH, OKLA., AND TAKES REFUGE IN THE FRIENDLY AISLES OF WAL-MART. IN SHORT ORDER, SOME ECCENTRIC, KINDLY STRANGERS "ADOPT" NOVALEE AND HER INFANT DAUGHTER, HELPING THEM BUCK THE ODDS AND BUILD A NEW LIFE.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> LAUGHTER IS HARDER... FRIENDSHIP IS STRONGER... TRUST IS DEEPER... WHEN IT COMES FROM THE HEART.
#
# Averge vote            : >>  6.9
# =====================================================================
#
#
# ---------------43 movie --------------
#
# Original title of movie: >> JAKOB THE LIAR
#
# Plot of the movie      : >> IN 1944 POLAND, A JEWISH SHOP KEEPER NAMED JAKOB IS SUMMONED TO GHETTO HEADQUARTERS AFTER BEING CAUGHT OUT AFTER CURFEW. WHILE WAITING FOR THE GERMAN KOMMONDANT, JAKOB OVERHEARS A GERMAN RADIO BROADCAST ABOUT RUSSIAN TROOP MOVEMENTS. RETURNED TO THE GHETTO, THE SHOPKEEPER SHARES HIS INFORMATION WITH A FRIEND AND THEN RUMORS FLY THAT THERE IS A SECRET RADIO WITHIN THE GHETTO.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> WHEN ALL HOPE WAS LOST, HE INVENTED IT.
#
# Averge vote            : >>  6
# =====================================================================
#
#
# ---------------44 movie --------------
#
# Original title of movie: >> ROMEO + JULIET
#
# Plot of the movie      : >> IN DIRECTOR BAZ LUHRMANN'S CONTEMPORARY TAKE ON WILLIAM SHAKESPEARE'S CLASSIC TRAGEDY, THE MONTAGUES AND CAPULETS HAVE MOVED THEIR ONGOING FEUD TO THE SWELTERING SUBURB OF VERONA BEACH, WHERE ROMEO AND JULIET FALL IN LOVE AND SECRETLY WED. THOUGH THE FILM IS VISUALLY MODERN, THE BARD'S DIALOGUE REMAINS.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> MY ONLY LOVE SPRUNG FROM MY ONLY HATE.
#
# Averge vote            : >>  6.7
# =====================================================================
#
#
# ---------------45 movie --------------
#
# Original title of movie: >> SLUMDOG MILLIONAIRE
#
# Plot of the movie      : >> JAMAL MALIK IS AN IMPOVERISHED INDIAN TEEN WHO BECOMES A CONTESTANT ON THE HINDI VERSION OF ‘WHO WANTS TO BE A MILLIONAIRE?’ BUT, AFTER HE WINS, HE IS SUSPECTED OF CHEATING.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> WHAT DOES IT TAKE TO FIND A LOST LOVE? A. MONEY, B. LUCK, C. SMARTS, D. DESTINY
#
# Averge vote            : >>  7.6
# =====================================================================
#
#
# ---------------46 movie --------------
#
# Original title of movie: >> BOBBY
#
# Plot of the movie      : >> IN 1968 THE LIVES OF A RETIRED DOORMAN, HOTEL MANAGER, LOUNGE SINGER, BUSBOY, BEAUTICIAN AND OTHERS INTERSECT IN THE WAKE OF ROBERT F. KENNEDY'S ASSASSINATION AT THE AMBASSADOR HOTEL IN LOS ANGELES.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> HE SAW WRONG AND TRIED TO RIGHT IT. HE SAW SUFFERING AND TRIED TO HEAL IT. HE SAW WAR AND TRIED TO STOP IT.
#
# Averge vote            : >>  6.4
# =====================================================================
#
#
# ---------------47 movie --------------
#
# Original title of movie: >> PARIS, JE T'AIME
#
# Plot of the movie      : >> OLIVIER ASSAYAS, GUS VAN SANT, WES CRAVEN AND ALFONSO CUARON ARE AMONG THE 20 DISTINGUISHED DIRECTORS WHO CONTRIBUTE TO THIS COLLECTION OF 18 STORIES, EACH EXPLORING A DIFFERENT ASPECT OF PARISIAN LIFE. THE COLOURFUL CHARACTERS IN THIS DRAMA INCLUDE A PAIR OF MIMES, A HUSBAND TRYING TO CHOSE BETWEEN HIS WIFE AND HIS LOVER, AND A MARRIED MAN WHO TURNS TO A PROSTITUTE FOR ADVICE.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> FALL IN LOVE WITH PARIS 18 TIMES.
#
# Averge vote            : >>  6.8
# =====================================================================
#
#
# ---------------48 movie --------------
#
# Original title of movie: >> THE CLAIM
#
# Plot of the movie      : >> A PROSPECTOR SELLS HIS WIFE AND DAUGHTER TO ANOTHER GOLD MINER FOR THE RIGHTS TO A GOLD MINE. TWENTY YEARS LATER, THE PROSPECTOR IS A WEALTHY MAN WHO OWNS MUCH OF THE OLD WEST TOWN NAMED KINGDOM COME. BUT CHANGES ARE BREWING AND HIS PAST IS COMING BACK TO HAUNT HIM. A SURVEYOR AND HIS CREW SCOUTS THE TOWN AS A LOCATION FOR A NEW RAILROAD LINE AND A YOUNG WOMAN SUDDENLY APPEARS IN THE TOWN AND IS EVIDENTLY THE MAN'S DAUGHTER.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> EVERYTHING HAS A PRICE.
#
# Averge vote            : >>  5.6
# =====================================================================
#
#
# ---------------49 movie --------------
#
# Original title of movie: >> ANTWONE FISHER
#
# Plot of the movie      : >> A SAILOR PRONE TO VIOLENT OUTBURSTS IS SENT TO A NAVAL PSYCHIATRIST FOR HELP. REFUSING AT FIRST TO OPEN UP, THE YOUNG MAN EVENTUALLY BREAKS DOWN AND REVEALS A HORRIFIC CHILDHOOD. THROUGH THE GUIDANCE OF HIS DOCTOR, HE CONFRONTS HIS PAINFUL PAST AND BEGINS A QUEST TO FIND THE FAMILY HE NEVER KNEW.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> ANTWONE FISHER IS AT WAR... WITH HIMSELF.
#
# Averge vote            : >>  6.7
# =====================================================================
#
#
# ---------------50 movie --------------
#
# Original title of movie: >> TRUE ROMANCE
#
# Plot of the movie      : >> CLARENCE MARRIES HOOKER ALABAMA, STEALS COCAINE FROM HER PIMP, AND TRIES TO SELL IT IN HOLLYWOOD, WHILE THE OWNERS OF THE COKE TRY TO RECLAIM IT.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> STEALING, CHEATING, KILLING. WHO SAID ROMANCE WAS DEAD?
#
# Averge vote            : >>  7.5
# =====================================================================
#
#
# ---------------51 movie --------------
#
# Original title of movie: >> TRADE
#
# Plot of the movie      : >> A TEXAS COP (KEVIN KLINE), WHOSE OWN DAUGHTER MIGHT HAVE BEEN FORCED INTO SEXUAL SLAVERY, JOINS FORCES WITH A MEXICAN YOUTH (CESAR RAMOS) TO FIND THE BOY'S SISTER, WHO WAS ABDUCTED AND FORCED INTO PROSTITUTION. MEANWHILE, A UKRAINIAN WOMAN WHO WAS PROMISED A BETTER LIFE IN AMERICA ALSO BECOMES A VICTIM.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> EACH YEAR, MORE THAN 1,000,000 PEOPLE ARE TRAFFICKED ACROSS INTERNATIONAL BORDERS... AGAINST THEIR WILL.
#
# Averge vote            : >>  6.8
# =====================================================================
#
#
# ---------------52 movie --------------
#
# Original title of movie: >> MY COUSIN VINNY
#
# ...
#
#
# ---------------77 movie --------------
#
# Original title of movie: >> THE BOOK OF MORMON MOVIE, VOLUME 1: THE JOURNEY
#
# Plot of the movie      : >> THE STORY OF LEHI AND HIS WIFE SARIAH AND THEIR FOUR SONS: LAMAN, LEMUEL, SAM, AND NEPHI. LEHI LEAVES JERUSALEM BECAUSE HE PROPHESIED UNTO THE PEOPLE CONCERNING THE DESTRUCTION OF JERUSALEM, AND THEY SOUGHT HIS LIFE. HE JOURNEYS INTO THE WILDERNESS WITH HIS FAMILY. HE SENDS NEPHI AND HIS BRETHREN BACK TO JERUSALEM AFTER THE BRASS PLATES AND THE FAMILY OF ISHMAEL. THE SONS AND DAUGHTERS OF LEHI MARRY THE SONS AND DAUGHTERS OF ISHMAEL. THEY TAKE THEIR FAMILIES AND CONTINUE INTO THE WILDERNESS. ISHMAEL DIES IN THE WILDERNESS. THEY COME TO THE SEA. NEPHI'S BRETHREN REBEL AGAINST HIM. HE CONFOUNDS THEM, AND BUILDS A SHIP. THEY CROSS THE SEA TO THE PROMISED LAND IN THE AMERICAS. LEHI DIES IN THE PROMISED LAND. NEPHI'S BRETHREN REBEL AGAINST HIM AGAIN. NEPHI DEPARTS AGAIN INTO THE WILDERNESS.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> 2600 YEARS AGO, ONE FAMILY BEGAN A REMARKABLE JOURNEY AND SET THE COURSE FOR A LATTER-DAY FAITH. THIS IS THEIR STORY.
#
# Averge vote            : >>  5
# =====================================================================
#
#
# ---------------78 movie --------------
#
# Original title of movie: >> THE VIRGINITY HIT
#
# Plot of the movie      : >> FOUR GUYS, ONE CAMERA, AND THEIR EXPERIENCE CHRONICLING THE EXHILARATING AND TERRIFYING RITE OF PASSAGE: LOSING YOUR VIRGINITY. AS THESE GUYS HELP THEIR BUDDY GET LAID, THEY'LL HAVE TO SURVIVE FRIENDS WITH BENEFITS, INTERNET HOOKUPS, EVEN PORN STARS DURING AN ADVENTURE THAT PROVES WHY YOU WILL ALWAYS REMEMBER YOUR FIRST TIME.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >>
#
# Averge vote            : >>  4.6
# =====================================================================
#
#
# ---------------79 movie --------------
#
# Original title of movie: >> JERUSALEMA
#
# Plot of the movie      : >> THIS SOUTH AFRICAN MOVIE TRACKS THE RISE OF A ONCE-PETTY CRIMINAL TO THE HEIGHTS OF THE CRIMINAL UNDERWORLD. AFTER CUTTING HIS TEETH ON HIJACKING, BEFORE MOVING ONTO BIGGER GAME, AN AMBITIOUS MAN HITS A SETBACK WHEN MOST OF HIS GANG ARE SHOT.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> WELCOME TO THE PROMISED LAND.
#
# Averge vote            : >>  6.8
# =====================================================================
#
#
# ---------------80 movie --------------
#
# Original title of movie: >> AJAMI
#
# Plot of the movie      : >> AJAMI IS AN AREA OF TEL AVIV IN ISRAEL WHERE ARABS, PALESTINIANS, JEWS AND CHRISTIANS LIVE TOGETHER IN A TENSE ATMOSPHERE. OMAR, AN ISRAELI ARAB, STRUGGLES TO SAVE HIS FAMILY FROM A GANG OF EXTORTIONISTS. HE ALSO COURTS A BEAUTIFUL CHRISTIAN GIRL: HADIR. MALEK, AN ILLEGAL PALESTINIAN WORKER, TRIES TO COLLECT ENOUGH MONEY TO PAY FOR HIS MOTHER'S OPERATION. DANDO, AN ISRAELI COP, DOES HIS UTMOST TO FIND HIS MISSING BROTHER WHO MAY HAVE BEEN KILLED BY PALESTINIANS.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >>
#
# Averge vote            : >>  6.8
# =====================================================================
#
#
# ---------------81 movie --------------
#
# Original title of movie: >> GUIANA 1838
#
# Plot of the movie      : >> THE ABOLITION OF SLAVERY IN THE BRITISH CARIBBEAN IN 1834 PROMPTS GILLANDERS, ARBUTHNOT &AMP; COMPANY IN CALCUTTA, A PART OF THE EAST INDIA COMPANY, TO RECRUIT COOLIES FROM INDIA TO FILL THE RESULTING LABOR VOID. THE COMPANY HIRES SINHA, A FIERCE SMALL-TIMER TO SELL DREAMS OF EL DORADO TO THE UNSUSPECTING, IMPOVERISHED COOLIES WHO ARE SIGNED TO FIVE-YEAR CONTRACTS AS INDENTURED SERVANTS. UPON THE COOLIES' ARRIVAL IN BRITISH GUIANA IN 1838, THE BRITISH PLANTERS PROMPTLY ENSLAVE THEM TO ENSURE THAT THE GROWTH OF SUGAR IN THE BRITISH WEST INDIES WILL CONTINUE UNINTERRUPTED. JOHN SCOBLE OF THE BRITISH AND FOREIGN ANTI SLAVERY SOCIETY ARRIVES ON THE COLONY A YEAR LATER TO DISCOVER A NEW FORM OF SLAVERY; THIS TIME ON THE BACKS OF INDIANS.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >>
#
# Averge vote            : >>  2.8
# =====================================================================
#
#
# ---------------82 movie --------------
#
# Original title of movie: >> TO SAVE A LIFE
#
# Plot of the movie      : >> JAKE TAYLOR HAS EVERYTHING. HE HAS A BEAUTIFUL GIRL, HE'S THE CHAMPION IN BASKETBALL AND BEER PONG, AND EVERYONE LOVES HIM. THEN, AN OLD CHILDHOOD FRIEND, WHOM JAKE USED TO BE FRIENDS WITH, COMMITS SUICIDE. JAKE BEGINS TO THINK. HE WONDERS WHAT HE COULD'VE DONE TO SAVE HIS FRIEND'S LIFE. A YOUTH MINISTER TELLS HIM THAT JAKE NEEDS GOD. SO JAKE BECOMES A CHRISTIAN. HOWEVER, THINGS BEGIN TO SPIN OUT OF CONTROL. HIS DAD IS CHEATING ON HIS MOM, HIS GIRLFRIEND IS PREGNANT, AND HIS FORMER FRIENDS RIDICULE AND MOCK HIM. DURING ALL THIS, JAKE IS GOING TO REALIZE JUST WHAT IT MEANS TO BE A CHRISTIAN AND HOW, TO SAVE A LIFE.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> SOME PEOPLE ARE JUST DYING TO BE HEARD.
#
# Averge vote            : >>  6.2
# =====================================================================
#
#
# ---------------83 movie --------------
#
# Original title of movie: >> THE BIRTH OF A NATION
#
# Plot of the movie      : >> NAT TURNER, A FORMER SLAVE IN AMERICA, LEADS A LIBERATION MOVEMENT IN 1831 TO FREE AFRICAN-AMERICANS IN VIRGINA THAT RESULTS IN A VIOLENT RETALIATION FROM WHITES.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >> THE UNTOLD STORY OF NAT TURNER
#
# Averge vote            : >>  6.5
# =====================================================================
#
#
# ---------------84 movie --------------
#
# Original title of movie: >> FLYWHEEL
#
# Plot of the movie      : >> JAY AUSTIN WANTS TO SELL YOU A USED CAR, BUT WATCH OUT! MANY VICTIMS HAVE FALLEN PREY TO HIS SMILING FACE AND HASTY PROMISES. AUSTIN DOES EVERYTHING HIS WAY UNTIL HIS DISHONESTY AND MANIPULATION ARE EXPOSED. LIKE MANY MEN, HE BECOMES DISGUSTED BY THE MASKS HE WEARS AND THE LIES HE TELLS. IN EVERY MAN'S LIFE, THERE CAN BE A TURNING POINT. WHEN JAY MAKES HIS TURN, HE NEVER LOOKS BACK.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >>
#
# Averge vote            : >>  6.8
# =====================================================================
#
#
# ---------------85 movie --------------
#
# Original title of movie: >> SIGNED, SEALED, DELIVERED
#
# Plot of the movie      : >> "SIGNED, SEALED, DELIVERED" INTRODUCES A DEDICATED QUARTET OF CIVIL SERVANTS IN THE DEAD LETTER OFFICE OF THE U.S. POSTAL SYSTEM WHO TRANSFORM THEMSELVES INTO AN ELITE TEAM OF LOST-MAIL DETECTIVES. THEIR DETERMINATION TO DELIVER THE SEEMINGLY UNDELIVERABLE TAKES THEM OUT OF THE POST OFFICE INTO AN UNPREDICTABLE WORLD WHERE LETTERS AND PACKAGES FROM THE PAST SAVE LIVES, SOLVE CRIMES, REUNITE OLD LOVES, AND CHANGE FUTURES BY ARRIVING LATE, BUT ALWAYS MIRACULOUSLY ON TIME.
#
# Runtime of the movie   : >> 120
#
# Tagline of the movie   : >>
#
# Averge vote            : >>  7
# =====================================================================
# Press enter to countinue
# ===================================================
# ~~~~~~~~~~~~~~   Movie search Engine   ~~~~~~~~~~~~~~
# ===================================================
# 1.     Show account information
# 2.     Change PIN number
# 3.     Movie search in the range of votes
# 4.     Movie search in Maximum and minimum duration
# 5.     Search movie by their titles
# 6.     View the names of random movies
# 7.     Play Hangman
# 8.     Terminate a program
# ==================================================
#
#
# Please enter the number of the servies that you want
#  or press enter to quit :
#  >6
# No. of movies You wants to see randomly !3
#
#
# ---------------1 movie --------------
#
# Original title of movie: >> FASCINATION
#
# Plot of the movie      : >> YOUNG SCOTT DOHERTY (ADAM GARCIA) GETS SUSPICIOUS WHEN HIS MOTHER (JACQUELINE BISSET) PLANS TO WED OLIVER VANCE (STUART WILSON) SOON AFTER HER HUSBAND'S UNTIMELY DEATH. SCOTT INVESTIGATES WITH OLIVER'S PRETTY DAUGHTER, KELLY (ALICE EVANS), WHO SHARED SCOTT'S DOUBTS ABOUT THE UPCOMING NUPTIALS. ALONG THE WAY, HE FALLS IN LOVE WITH KELLY, BUT A FATAL EXPLOSION TURNS SCOTT'S LIFE UPSIDE DOWN - AND THE EVIDENCE POINTS TO HIM AS THE MURDERER. HAS HE BEEN FRAMED?
#
# Runtime of the movie   : >> 95
#
# Tagline of the movie   : >>
#
# Averge vote            : >>  3.8
# =====================================================================
#
#
# ---------------2 movie --------------
#
# Original title of movie: >> CHICKEN TIKKA MASALA
#
# Plot of the movie      : >> JIMI (CHRIS BISSON), THE CHOPRA FAMILY'S ONLY SON, GETS CAUGHT OFF GUARD WHEN HIS HIGH-HANDED PARENTS (SAEED JAFFREY AND JAMILA MASSEY) ANNOUNCE AN ARRANGED MARRIAGE TO SIMRAN (JINDER MAHAL), A LOVELY GIRL FROM A RESPECTABLE FAMILY. PROBLEM IS, JIMI'S GAY, SO TO HIDE HIS HOMOSEXUALITY, HE SPINS AN EVER-MORE ELABORATE WEB OF DECEIT -- BUT HOW LONG CAN HE CONCEAL THE TRUTH?
#
# Runtime of the movie   : >> 90
#
# Tagline of the movie   : >>
#
# Averge vote            : >>  3.5
# =====================================================================
#
#
# ---------------3 movie --------------
#
# Original title of movie: >> THE DESCENDANTS
#
# Plot of the movie      : >> WITH HIS WIFE ELIZABETH ON LIFE SUPPORT AFTER A BOATING ACCIDENT, HAWAIIAN LAND BARON, MATT KING TAKES HIS DAUGHTERS ON A TRIP FROM OAHU TO KAUAI TO CONFRONT THE YOUNG REAL ESTATE BROKER, WHO WAS HAVING AN AFFAIR WITH ELIZABETH BEFORE HER MISFORTUNE.
#
# Runtime of the movie   : >> 115
#
# Tagline of the movie   : >> THE SOUTH PACIFIC AIN'T THAT TERRIFIC.
#
# Averge vote            : >>  6.7
# =====================================================================
# Press enter to countinue
# ===================================================
# ~~~~~~~~~~~~~~   Movie search Engine   ~~~~~~~~~~~~~~
# ===================================================
# 1.     Show account information
# 2.     Change PIN number
# 3.     Movie search in the range of votes
# 4.     Movie search in Maximum and minimum duration
# 5.     Search movie by their titles
# 6.     View the names of random movies
# 7.     Play Hangman
# 8.     Terminate a program
# ==================================================
#
#
# Please enter the number of the servies that you want
#  or press enter to quit :
#  >6
# No. of movies You wants to see randomly !2
#
#
# ---------------1 movie --------------
#
# Original title of movie: >> STORMBREAKER
#
# Plot of the movie      : >> ALEX RIDER THINKS HE IS A NORMAL SCHOOL BOY, UNTIL HIS UNCLE IS KILLED. HE DISCOVERS THAT HIS UNCLE WAS ACTUALLY SPY ON A MISSION, WHEN HE WAS KILLED. ALEX IS RECRUITED BY ALAN BLUNT TO CONTINUE THE MISSION. HE IS SENT TO CORNWALL TO INVESTIGATE A NEW COMPUTER SYSTEM, WHICH DARRIUS SAYLE HAS CREATED. HE PLANS TO GIVE THE NEW COMPUTER SYSTEMS TO EVERY SCHOOL IN THE COUNTRY, BUT MR. BLUNT HAS OTHER IDEAS AND ALEX MUST FIND OUT WHAT IT IS.
#
# Runtime of the movie   : >> 93
#
# Tagline of the movie   : >> RULE THE SCHOOL. SAVE THE WORLD.
#
# Averge vote            : >>  5.1
# =====================================================================
#
#
# ---------------2 movie --------------
#
# Original title of movie: >> THE LONE RANGER
#
# Plot of the movie      : >> THE TEXAS RANGERS CHASE DOWN A GANG OF OUTLAWS LED BY BUTCH CAVENDISH, BUT THE GANG AMBUSHES THE RANGERS, SEEMINGLY KILLING THEM ALL. ONE SURVIVOR IS FOUND, HOWEVER, BY AN AMERICAN INDIAN NAMED TONTO, WHO NURSES HIM BACK TO HEALTH. THE RANGER, DONNING A MASK AND RIDING A WHITE STALLION NAMED SILVER, TEAMS UP WITH TONTO TO BRING THE UNSCRUPULOUS GANG AND OTHERS OF THAT ILK TO JUSTICE.
#
# Runtime of the movie   : >> 149
#
# Tagline of the movie   : >> NEVER TAKE OFF THE MASK
#
# Averge vote            : >>  5.9
# =====================================================================
# Press enter to countinue
# ===================================================
# ~~~~~~~~~~~~~~   Movie search Engine   ~~~~~~~~~~~~~~
# ===================================================
# 1.     Show account information
# 2.     Change PIN number
# 3.     Movie search in the range of votes
# 4.     Movie search in Maximum and minimum duration
# 5.     Search movie by their titles
# 6.     View the names of random movies
# 7.     Play Hangman
# 8.     Terminate a program
# ==================================================
#
#
# Please enter the number of the servies that you want
#  or press enter to quit :
#  >7
# H A N G M A N
#              A game of words
# -----------------------------------
# Type "1" to play the game, "2" to go back to menu 1
#
# ------
# Input a letter: p
#
# p-----
# Input a letter: y
#
# py----
# Input a letter: t
#
# pyt---
# Input a letter: h
#
# pyth--
# Input a letter: o
#
# pytho-
# Input a letter: n
# You guessed the word!
# You survived!
#
# Type "1" to play the game, "2" to go back to menu 2
# ===================================================
# ~~~~~~~~~~~~~~   Movie search Engine   ~~~~~~~~~~~~~~
# ===================================================
# 1.     Show account information
# 2.     Change PIN number
# 3.     Movie search in the range of votes
# 4.     Movie search in Maximum and minimum duration
# 5.     Search movie by their titles
# 6.     View the names of random movies
# 7.     Play Hangman
# 8.     Terminate a program
# ==================================================
#
#
# Please enter the number of the servies that you want
#  or press enter to quit :
#  >8
#
#                                         __
#  ______________________________________/ /_____________________________________
# /_____/_____/_____/_____/_____/_____/_  __/_____/_____/_____/_____/_____/_____/
#                                      /_/
#
#
#     __  ___          __                 _ __  __
#    /  |/  /___ _____/ /__     _      __(_) /_/ /_
#   / /|_/ / __ `/ __  / _ \   | | /| / / / __/ __ \
#  / /  / / /_/ / /_/ /  __/   | |/ |/ / / /_/ / / /
# /_/  /_/\__,_/\__,_/\___/    |__/|__/_/\__/_/ /_/
#
#     __                __   _____
#    / /___ _   _____  / /  |__  /
#   / / __ \ | / / _ \/ /    /_ <   ______
#  / / /_/ / |/ /  __/\ \  ___/ /  /_____/
# /_/\____/|___/\___/  \_\/____/
#
#
#     ____           _____           ____                     __
#    / __ )__  __   / ___/__  ______/ / /_  ____ _____  _____/ /_  __  __
#   / __  / / / /   \__ \/ / / / __  / __ \/ __ `/ __ \/ ___/ __ \/ / / /
#  / /_/ / /_/ /   ___/ / /_/ / /_/ / / / / /_/ / / / (__  ) / / / /_/ /
# /_____/\__, /   /____/\__,_/\__,_/_/ /_/\__,_/_/ /_/____/_/ /_/\__,_/
#       /____/
#   _______                     _
#  /_  __(_)      ______ ______(_)
#   / / / / | /| / / __ `/ ___/ /
#  / / / /| |/ |/ / /_/ / /  / /
# /_/ /_/ |__/|__/\__,_/_/  /_/
#
#
#
#                                         __
#  ______________________________________/ /_____________________________________
# /_____/_____/_____/_____/_____/_____/_  __/_____/_____/_____/_____/_____/_____/
#                                      /_/
#
#            +-+-+-+-+-+-+-+ +-+-+-+ +-+-+-+ +-+-+ +-+-+-+-+-+-+ +-+-+-+-+-+
#           |W|a|i|t|i|n|g| |f|o|r| |y|o|u| |t|o| |b|r|o|w|s|e| |m|o|v|i|e|
#           +-+-+-+-+-+-+-+ +-+-+-+ +-+-+-+ +-+-+ +-+-+-+-+-+-+ +-+-+-+-+-+
# +-+-+-+-+-+
# |a|g|a|i|n|
# +-+-+-+-+-+
#
#                                         __
#  ______________________________________/ /_____________________________________
# /_____/_____/_____/_____/_____/_____/_  __/_____/_____/_____/_____/_____/_____/
#                                      /_/
